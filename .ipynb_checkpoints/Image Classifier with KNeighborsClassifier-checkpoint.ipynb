# %% [markdown]
# **Programmer:** python_scripts (Abhijith Warrier)
#
# **PYTHON SCRIPT TO **_BUILD AN IMAGE CLASSIFIER WITH KNeighborsClassifier ON THE SKLEARN DIGITS DATASET_**. 🐍🖼️🔢**
#
# This script loads the classic **handwritten digits (8×8 images)** dataset from scikit-learn, trains a **K-Nearest Neighbors (KNN)** classifier, evaluates accuracy, and visualizes a few predictions.

# %% [markdown]
# ### 📦 Import Required Libraries
#
# We’ll use scikit-learn for data, model, and metrics; matplotlib for quick visuals.

# %%
# Import dataset, split utility, model, and metrics
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, ConfusionMatrixDisplay

# Plotting
import matplotlib.pyplot as plt

# %% [markdown]
# ### 📥 Load the Digits Dataset
#
# Each sample is an 8×8 grayscale image (values 0–16) with a label 0–9.

# %%
# Load digits dataset
digits = load_digits()
X, y = digits.data, digits.target   # X: (n_samples, 64), y: digit labels 0..9

# (Optional) Peek at shapes
print("Feature matrix shape:", X.shape)
print("Targets shape:", y.shape)
# Out:
# Feature matrix shape: (1797, 64)
# Targets shape: (1797,)

# %% [markdown]
# ### ✂️ Split into Train/Test Sets
#
# We keep a test set to estimate generalization to unseen images.

# %%
# Stratified split keeps class balance across train/test
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y
)

# %% [markdown]
# ### 🤖 Initialize and Train the KNN Classifier
#
# KNN classifies by majority vote among the k closest samples (here k=3).

# %%
# Create KNN with k=3 neighbors (good starting point)
knn = KNeighborsClassifier(n_neighbors=3)

# Fit on training data
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# ### 🔮 Predict and Evaluate
#
# We’ll compute accuracy and print a per-class report.

# %%
# Predict on the held-out test set
y_pred = knn.predict(X_test)

# Overall accuracy
acc = accuracy_score(y_test, y_pred)
print(f"Test Accuracy: {acc:.4f}")

# Per-class precision/recall/F1
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Test Accuracy: 0.9844
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        45
#            1       0.94      1.00      0.97        46
#            2       1.00      1.00      1.00        44
#            3       1.00      1.00      1.00        46
#            4       0.98      1.00      0.99        45
#            5       1.00      0.98      0.99        46
#            6       0.98      1.00      0.99        45
#            7       1.00      1.00      1.00        45
#            8       0.97      0.91      0.94        43
#            9       0.98      0.96      0.97        45
#
#     accuracy                           0.98       450
#    macro avg       0.98      0.98      0.98       450
# weighted avg       0.98      0.98      0.98       450

# %% [markdown]
# ### 📊 Visualize the Confusion Matrix (Optional)
#
# Helps see which digits are getting confused.

# %%
# Confusion matrix display
disp = ConfusionMatrixDisplay.from_predictions(y_test, y_pred, cmap="Blues")
disp.ax_.set_title("KNN (k=3) — Confusion Matrix")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 🖼️ Visualize a Few Predictions (Optional)
#
# Show sample images with predicted vs. true labels.

# %%
# Plot a few test images with predictions
fig, axes = plt.subplots(2, 5, figsize=(10, 4))
fig.suptitle("Sample Predictions (Top: image | Bottom: pred/true)", y=1.05)

for ax_idx, ax in enumerate(axes.flat):
    # Choose an index from the test set
    idx = ax_idx
    image = X_test[idx].reshape(8, 8)   # reshape back to 8x8
    ax.imshow(image, cmap="gray")
    ax.axis("off")

# Add a second row of text labels
for i, ax in enumerate(axes.flat):
    if i >= 10: break
plt.figure(figsize=(10, 1))
for i in range(10):
    plt.text(i + 0.25, 0.5, f"pred:{y_pred[i]} | true:{y_test[i]}", fontsize=10)

plt.axis("off")
plt.show()

# %% [markdown]
# ### 💡 Notes
# - KNN often benefits from feature scaling; here, pixel values are already on a small range (0–16), so it’s optional.
# - You can tune n_neighbors (e.g., 3, 5, 7) or weight votes by distance: weights="distance".
# - For a quick hyperparameter search, combine this with GridSearchCV.
