# %% [markdown]
# **Programmer:** python_scripts (Abhijith Warrier)
#
# **PYTHON SCRIPT TO *LOG MACHINE LEARNING PREDICTIONS WITH TIMESTAMPS FOR MONITORING AND AUDITING*. 🧠📝⏱️**
#
# This script demonstrates how to build a simple ML prediction logging system that stores:
#
# - prediction results
# - prediction probabilities
# - input values
# - timestamps
#
# Such logging is critical in real-world ML systems for monitoring, debugging, auditing, and drift analysis.

# %% [markdown]
# ---

# %% [markdown]
# ## **📦 Import Required Libraries**

# %%
import pandas as pd
from datetime import datetime

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ---

# %% [markdown]
# ## **🧩 Load Dataset**

# %%
data = load_breast_cancer()

X = pd.DataFrame(data.data, columns=data.feature_names)
y = data.target

# %% [markdown]
# ---

# %% [markdown]
# ## **✂️ Split Data**

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42,
    stratify=y
)

# %% [markdown]
# ---

# %% [markdown]
# ## **🤖 Train Model**

# %%
model = LogisticRegression(max_iter=5000)

model.fit(X_train, y_train)

# %% [markdown]
# ---

# %% [markdown]
# ## **📊 Generate Predictions**

# %%
sample_data = X_test.iloc[:5]

predictions = model.predict(sample_data)

prediction_probs = model.predict_proba(sample_data)[:, 1]

# %% [markdown]
# ---

# %% [markdown]
# ## **📝 Create Prediction Logs**
#
# We create structured logs for each prediction.

# %%
logs = []

for i in range(len(sample_data)):

    log_entry = {
        "timestamp": datetime.now(),
        "prediction": int(predictions[i]),
        "prediction_probability": float(prediction_probs[i]),
        "mean_radius": sample_data.iloc[i]["mean radius"],
        "mean_texture": sample_data.iloc[i]["mean texture"]
    }

    logs.append(log_entry)

# %% [markdown]
# ---

# %% [markdown]
# ## **📂 Convert Logs to DataFrame**

# %%
logs_df = pd.DataFrame(logs)

print(logs_df)

# %% [markdown]
# ---

# %% [markdown]
# ## **💾 Save Logs to CSV**

# %%
logs_df.to_csv("prediction_logs.csv", index=False)

print("Prediction logs saved successfully.")

# %% [markdown]
# ---

# %% [markdown]
# ## **🔍 Why Prediction Logging Matters**
#
# Prediction logging helps with:
#
# - model monitoring
# - debugging production issues
# - tracking model behavior
# - auditing ML systems
# - detecting drift over time
#
# Without logs, production ML systems become difficult to analyze.

# %% [markdown]
# ---

# %% [markdown]
# ## **🧠 Real-World ML Logging Includes**
#
# Production systems often log:
#
# - prediction timestamp
# - model version
# - input features
# - prediction confidence
# - user/session IDs
# - latency metrics

# %% [markdown]
# ---

# %% [markdown]
# ## **🧠 Key Takeaways**
#
# 1. Prediction logging is critical in production ML systems.
# 2. Timestamps help track model behavior over time.
# 3. Logging supports monitoring, debugging, and auditing.
# 4. Structured logs simplify ML operations.
# 5. Production ML requires more than just model training.

# %% [markdown]
# ---

# %% [markdown]
# ## **Conclusion**
#
# Machine learning systems do not end with predictions — they require monitoring, auditing, and operational visibility. Logging predictions with timestamps is a foundational step toward building reliable and production-ready ML systems.
#
# This strengthens the **ML Systems** track in the **AI with Python** series — focusing on practical engineering workflows around machine learning models.

# %% [markdown]
# ---
