# %% [markdown]
# **Programmer:** python_scripts (Abhijith Warrier)
#
# **PYTHON SCRIPT TO _BUILD A COMPLETE MACHINE LEARNING WORKFLOW FROM DATA PREPROCESSING TO MODEL EVALUATION_. 🧠🚀📊**
#
# This project brings together everything you’ve learned throughout the **AI with Python** series into a single end-to-end machine learning workflow. The pipeline includes:
# - Data Loading
# - Data Cleaning
# - Feature Engineering
# - Data Splitting
# - Model Training
# - Model Evaluation
# - Model Saving
# - Prediction
# - Logging
# - Deployment Readiness
# This serves as the capstone project for the **ML Systems** track.

# %% [markdown]
# ---

# %% [markdown]
# ## **📦 Import Required Libraries**

# %%
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix
)
import joblib

# %% [markdown]
# ---

# %% [markdown]
# ## **🧩 Load Dataset**

# %%
data = load_breast_cancer()

X = pd.DataFrame(
    data.data,
    columns=data.feature_names
)

y = data.target

# %% [markdown]
# ---

# %% [markdown]
# ## **🧹 Create Complete ML Pipeline**

# %%
pipeline = Pipeline([

    (
        "imputer",
        SimpleImputer(strategy="median")
    ),

    (
        "scaler",
        StandardScaler()
    ),

    (
        "classifier",
        RandomForestClassifier(
            n_estimators=200,
            random_state=42
        )
    )

])

# %% [markdown]
# ---

# %% [markdown]
# ## **✂️ Split Dataset**

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.30,
    random_state=42,
    stratify=y
)

# %% [markdown]
# ---

# %% [markdown]
# ## **🤖 Train Model**

# %%
pipeline.fit(
    X_train,
    y_train
)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                 ('scaler', StandardScaler()),
#                 ('classifier',
#                  RandomForestClassifier(n_estimators=200, random_state=42))])

# %% [markdown]
# ---

# %% [markdown]
# ## **📊 Generate Predictions**

# %%
predictions = pipeline.predict(
    X_test
)

# %% [markdown]
# ---

# %% [markdown]
# ## **📈 Evaluate Model**

# %%
print(
    "Accuracy:",
    accuracy_score(
        y_test,
        predictions
    )
)

print(
    "Precision:",
    precision_score(
        y_test,
        predictions
    )
)

print(
    "Recall:",
    recall_score(
        y_test,
        predictions
    )
)

print(
    "F1:",
    f1_score(
        y_test,
        predictions
    )
)
# Out:
# Accuracy: 0.9415204678362573
# Precision: 0.944954128440367
# Recall: 0.9626168224299065
# F1: 0.9537037037037037

# %% [markdown]
# ---

# %% [markdown]
# ## **🔍 View Confusion Matrix**

# %%
cm = confusion_matrix(
    y_test,
    predictions
)

print(cm)
# Out:
# [[ 58   6]
#  [  4 103]]

# %% [markdown]
# ---

# %% [markdown]
# ## **💾 Save Complete Pipeline**

# %%
joblib.dump(
    pipeline,
    "breast_cancer_pipeline.pkl"
)
# Out:
# ['breast_cancer_pipeline.pkl']

# %% [markdown]
# ---

# %% [markdown]
# ## **📂 Load Saved Pipeline**

# %%
loaded_pipeline = joblib.load(
    "breast_cancer_pipeline.pkl"
)

# %% [markdown]
# ---

# %% [markdown]
# ## **🚀 Predict New Samples**

# %%
new_predictions = loaded_pipeline.predict(
    X_test.iloc[:5]
)

print(new_predictions)
# Out:
# [0 1 1 0 1]

# %% [markdown]
# ---

# %% [markdown]
# ## **📝 Create Prediction Logs**

# %%
logs = pd.DataFrame({
    "Actual": y_test[:5],
    "Prediction": new_predictions
})

print(logs)
# Out:
#    Actual  Prediction
# 0       0           0
# 1       1           1
# 2       1           1
# 3       0           0
# 4       0           1

# %% [markdown]
# ---

# %% [markdown]
# ## **🎯 Workflow Recap**
#
# This project combines:
#
# ✔ Data Loading
#
# ✔ Data Preprocessing
#
# ✔ Missing Value Handling
#
# ✔ Feature Scaling
#
# ✔ Pipeline Building
#
# ✔ Model Training
#
# ✔ Model Evaluation
#
# ✔ Model Persistence
#
# ✔ Prediction
#
# ✔ Logging

# %% [markdown]
# ---

# %% [markdown]
# ## **🧠 Key Takeaways**
#
# 1. Production ML requires more than model training.
# 2. Pipelines make preprocessing consistent.
# 3. Evaluation metrics validate model quality.
# 4. Saving the pipeline simplifies deployment.
# 5. End-to-end workflows are the foundation of ML Systems.

# %% [markdown]
# ---

# %% [markdown]
# ## **Conclusion**
#
# From preprocessing and model building to deployment concepts, monitoring, drift detection, shadow deployments, A/B testing, dashboards, and complete production workflows, you’ve explored the essential building blocks used by modern ML engineers.
#
# This capstone project ties everything together into a single, production-ready workflow and marks the completion of the first **AI with Python** journey.

# %% [markdown]
# ---
