# %% [markdown]
# **Programmer:** python_scripts (Abhijith Warrier)
#
# **PYTHON SCRIPT TO **_USE THE ELBOW METHOD TO FIND THE OPTIMAL k IN K-MEANS CLUSTERING_**. 🐍📈️📊**
#
# This script demonstrates how to apply the **Elbow Method** to choose the right number of clusters (k) for **K-Means**. We’ll calculate the inertia **(within-cluster sum of squares)** for different values of k and plot them to identify the “elbow point.

# %% [markdown]
# ### 📦 Import Required Libraries
#
# We’ll use pandas, scikit-learn, numpy, and matplotlib.

# %%
# Core libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %% [markdown]
# ### 🧮 Create a Customer Dataset
#
# We’ll reuse a synthetic dataset with Annual Income and Spending Score.

# %%
# Demo dataset
data = {
    "CustomerID": range(1, 21),
    "AnnualIncome_k$": [15, 16, 17, 18, 20, 22, 25, 28, 30, 33, 60, 62, 65, 68, 70, 72, 75, 78, 80, 85],
    "SpendingScore":   [18, 20, 22, 25, 28, 30, 35, 40, 42, 45, 55, 58, 60, 62, 65, 66, 68, 70, 72, 75],
}
df = pd.DataFrame(data)

features = ["AnnualIncome_k$", "SpendingScore"]
X = df[features].values

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ### 🔢 Apply K-Means for Different k Values
#
# We loop through values of k and store the inertia.

# %%
inertia = []

# Try k from 1 to 10
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, n_init=10, random_state=42)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

# %% [markdown]
# ### 📈 Plot the Elbow Curve
#
# We look for the point where the inertia stops decreasing sharply.

# %%
plt.figure(figsize=(7, 5))
plt.plot(range(1, 11), inertia, marker="o", linestyle="--", color="b")
plt.title("Elbow Method for Optimal k")
plt.xlabel("Number of clusters (k)")
plt.ylabel("Inertia (WCSS)")
plt.xticks(range(1, 11))
plt.grid(True)
plt.show()

# %% [markdown]
# ### ✅ Notes
# - The elbow point (often around k=3–5 for customer data) indicates a good trade-off.
# - Too few clusters → underfitting (too broad).
# - Too many clusters → overfitting (clusters lose meaning).
