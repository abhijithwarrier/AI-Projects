# %% [markdown]
# **PYTHON SCRIPT TO _HANDLE IMBALANCED CLASSIFICATION USING SMOTE AND CLASS WEIGHTS._ 🧠⚖️📊**
#
# This script demonstrates how to handle imbalanced datasets using two practical approaches:
#
# - **SMOTE** → creates synthetic minority-class samples
# - **class_weight** → changes how strongly the model penalizes minority-class mistakes

# %% [markdown]
# ---

# %% [markdown]
# ## **📦 Import Required Libraries**

# %%
import pandas as pd

from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

from imblearn.over_sampling import SMOTE

# %% [markdown]
# ---

# %% [markdown]
# ## **🧩 Create an Imbalanced Dataset**

# %%
X, y = make_classification(
    n_samples=5000,
    n_features=10,
    n_informative=6,
    n_redundant=2,
    weights=[0.90, 0.10],
    random_state=42
)

X = pd.DataFrame(X, columns=[f"feature_{i}" for i in range(10)])
y = pd.Series(y, name="target")

# %% [markdown]
# ---

# %% [markdown]
# ## **✂️ Split Data into Train and Test Sets**

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42,
    stratify=y
)

# %% [markdown]
# ---

# %% [markdown]
# ## **🚨 Train Baseline Model**

# %%
baseline_model = LogisticRegression(max_iter=5000)
baseline_model.fit(X_train, y_train)

baseline_pred = baseline_model.predict(X_test)

print("=== Baseline Model ===")
print(classification_report(y_test, baseline_pred))
print(confusion_matrix(y_test, baseline_pred))
# Out:
# === Baseline Model ===
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      1343
#            1       0.66      0.15      0.24       157
#
#     accuracy                           0.90      1500
#    macro avg       0.78      0.57      0.59      1500
# weighted avg       0.88      0.90      0.87      1500
#
# [[1331   12]
#  [ 134   23]]

# %% [markdown]
# ---

# %% [markdown]
# ## **🔁 Approach 1 – SMOTE**

# %%
smote = SMOTE(random_state=42)

X_train_smote, y_train_smote = smote.fit_resample(
    X_train,
    y_train
)

# %% [markdown]
# ---

# %% [markdown]
# ## **🤖 Train Model with SMOTE Data**

# %%
smote_model = LogisticRegression(max_iter=5000)
smote_model.fit(X_train_smote, y_train_smote)

smote_pred = smote_model.predict(X_test)

print("=== SMOTE Model ===")
print(classification_report(y_test, smote_pred))
print(confusion_matrix(y_test, smote_pred))
# Out:
# === SMOTE Model ===
#               precision    recall  f1-score   support
#
#            0       0.97      0.76      0.85      1343
#            1       0.28      0.80      0.41       157
#
#     accuracy                           0.76      1500
#    macro avg       0.62      0.78      0.63      1500
# weighted avg       0.90      0.76      0.80      1500
#
# [[1014  329]
#  [  32  125]]

# %% [markdown]
# ---

# %% [markdown]
# ## **⚖️ Approach 2 – class_weight**

# %%
weighted_model = LogisticRegression(
    max_iter=5000,
    class_weight="balanced"
)

weighted_model.fit(X_train, y_train)

weighted_pred = weighted_model.predict(X_test)

print("=== class_weight Model ===")
print(classification_report(y_test, weighted_pred))
print(confusion_matrix(y_test, weighted_pred))
# Out:
# === class_weight Model ===
#               precision    recall  f1-score   support
#
#            0       0.97      0.76      0.85      1343
#            1       0.28      0.81      0.42       157
#
#     accuracy                           0.76      1500
#    macro avg       0.63      0.78      0.63      1500
# weighted avg       0.90      0.76      0.81      1500
#
# [[1017  326]
#  [  30  127]]

# %% [markdown]
# ---

# %% [markdown]
# ## **🔍 SMOTE vs class_weight**
#
# - **SMOTE** changes the training data by generating synthetic minority samples.
# - **class_weight** keeps the data unchanged but increases penalty for minority-class mistakes.
# - Both approaches are useful when accuracy alone is misleading.

# %% [markdown]
# ---

# %% [markdown]
# ## **🧠 Key Takeaways**
#
# 1. Imbalanced data can make models ignore the minority class.
# 2. SMOTE creates synthetic minority-class samples.
# 3. `class_weight="balanced"` adjusts model learning without resampling.
# 4. Recall and F1-score are more useful than accuracy for imbalanced data.
# 5. The best method depends on your data, model, and business objective.

# %% [markdown]
# ---

# %% [markdown]
# ## **Conclusion**
#
# Handling imbalanced data is essential in real-world ML problems like fraud detection, churn prediction, and medical diagnosis. SMOTE and class_weight provide two practical ways to help models learn from rare but important classes.

# %% [markdown]
# ---
